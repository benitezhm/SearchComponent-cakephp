# %% [markdown]
# <a href="https://colab.research.google.com/github/benitezhm/SearchComponent-cakephp/blob/master/trainings/trainings_general_trainings_in_l1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Template - Training topics for general trainings in L1:
#
# Reference: https://iapp.org/news/a/how-to-implement-effective-privacy-training
#
#
# 1.   Types of personal data potentially processed (several examples - who they belong to).
# 2.   Processing purposes for the personal data processed (several examples - why do we need it? Do we actually need it?)
# 3.   Privacy principles (Lawfulness, Fairness and Transparency; Purpose Limitation; Data Minimisation; Accuracy; Storage Limitation; Integrity and Confidentiality; and Accountability) and examples of violations (broad).
# 4.   Organizational contacts/policies/procedures: Help trainees understand the organization's actions related to protecting privacy and the employee's role in the privacy ecosystem. This should include an overview of the privacy team's responsibilities, information on internal policies and procedures, and examples of when employees should give the privacy team a jingle — or Slack or email.
# 5.   The ÑAPA: How to interact with the privacy team while doing a RoPA or DPIA and ensure a quick process? What should you prepare and bring to the table in advance? What does the privacy team want to know? *we may include a pre-assesment for this section, (sort of a checklist of what to do), we will use a link instead of a video for this section, and it will be optional.*
